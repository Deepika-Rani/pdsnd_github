# %% [markdown]
# ### Explore Bike Share Data
#
# For this project, your goal is to ask and answer three questions about the available bikeshare data from Washington, Chicago, and New York.  This notebook can be submitted directly through the workspace when you are confident in your results.
#
# You will be graded against the project [Rubric](https://review.udacity.com/#!/rubrics/2508/view) by a mentor after you have submitted.  To get you started, you can use the template below, but feel free to be creative in your solutions!

# %% [markdown]
# # Question 1.
# # Popular times of travel
# ### What is the common month of travel in Newyork?

# %%
# Your solution code goes here
## What is the popular times of travel in 
## New York
## Washington
## chicago
newyork = read.csv('new_york_city.csv')
wash = read.csv('washington.csv')
chi = read.csv('chicago.csv')

## installatin of lubridate package
library(tidyverse)

library(lubridate)

## New York City
## 1.  the most common month of travel

datetime <- ymd_hms(newyork$Start.Time)
Most.Often.Month <- table(month(datetime))
Most.Often.Month.df <- as.data.frame(Most.Often.Month)
names(Most.Often.Month.df) <- c("month", "count")
Most.Often.Month.df

## visual representation 

ggplot(Most.Often.Month.df, aes(x= month, y = count, group = 1)) +
  geom_line(state = "identity")+
  labs(title = "this plot represents months of travel")
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.0     ✔ readr   1.3.1
# ✔ tibble  2.0.1     ✔ purrr   0.2.5
# ✔ tidyr   0.8.2     ✔ stringr 1.3.1
# ✔ ggplot2 3.1.0     ✔ forcats 0.3.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Attaching package: ‘lubridate’
#
# The following object is masked from ‘package:base’:
#
#     date
#   month count
# 1 1      5745
# 2 2      6364
# 3 3      5820
# 4 4     10661
# 5 5     12180
# 6 6     14000
# Warning message:
# “Ignoring unknown parameters: state”
# plot without title

# %% [markdown]
# **The graphs clearly shows the June is the most common month of travel**

# %% [markdown]
# ###  What is the common month of travel in Washington?

# %%
## Washington
## the most common month of travel
datetime <- ymd_hms(wash$Start.Time)
Most.Often.Month <- table(month(datetime))
Most.Often.Month.df <- as.data.frame(Most.Often.Month)
names(Most.Often.Month.df) <- c("month", "count")
Most.Often.Month.df

## visual representation 

ggplot(Most.Often.Month.df, aes(x= month, y = count, group = 1)) +
  geom_line(state = "identity")+
  labs(title = "this plot represents months of travel")
# Out:
#   month count
# 1 1      8946
# 2 2     11563
# 3 3     12612
# 4 4     18522
# 5 5     17072
# 6 6     20335
# Warning message:
# “Ignoring unknown parameters: state”
# plot without title

# %% [markdown]
# **The above plot clearly shows that June is the most common month to travel in Washington.**

# %% [markdown]
# ###  What is the common month of travel in Chicago city?

# %%
## Chicago city
## the most common month of travel
datetime <- ymd_hms(chi$Start.Time)
Most.Often.Month <- table(month(datetime))
Most.Often.Month.df <- as.data.frame(Most.Often.Month)
names(Most.Often.Month.df) <- c("month", "count")
Most.Often.Month.df

## visual representation 

ggplot(Most.Often.Month.df, aes(x= month, y = count, group = 1)) +
  geom_line(state = "identity")+
  labs(title = "this plot represents months of travel")
# Out:
#   month count
# 1 1      650
# 2 2      930
# 3 3      803
# 4 4     1526
# 5 5     1905
# 6 6     2816
# Warning message:
# “Ignoring unknown parameters: state”
# plot without title

# %% [markdown]
# **The above plot represents that June is the most common month.**

# %% [markdown]
#
# ###  What is the common day of week in New York?

# %%
## what is the most common day of week to travel?

##New York city
## most common day of week?

datetime <- ymd_hms(newyork$Start.Time)
Most.Often.Day <- table(wday(datetime, abbr = FALSE))
Most.Often.Day.df <- as.data.frame(Most.Often.Day)
names(Most.Often.Day.df) <- c("Week_days", "count")
Most.Often.Day.df 



## visual representation of data

ggplot(Most.Often.Day.df, aes(x= Week_days, y = count, group = 1)) +
  geom_line(state = "identity")+
  labs(title = "this plot represents week days of travel")
# Out:
#   Week_days count
# 1 1         6597
# 2 2         7570
# 3 3         7898
# 4 4         9632
# 5 5         8729
# 6 6         8168
# 7 7         6176
# Warning message:
# “Ignoring unknown parameters: state”
# plot without title

# %% [markdown]
# **Wednesday is the common day of week in New York**

# %% [markdown]
# ### What is the common day of week in Washington?

# %%
## Washington city
## most common day of week?

datetime <- ymd_hms(wash$Start.Time)
Most.Often.Day <- table(wday(datetime, abbr = FALSE))
Most.Often.Day.df <- as.data.frame(Most.Often.Day)
names(Most.Often.Day.df) <- c("Week_days", "count")
Most.Often.Day.df 
## visual representation of data

ggplot(Most.Often.Day.df, aes(x= Week_days, y = count, group = 1)) +
  geom_line(state = "identity")+
  labs(title = "this plot represents week days of travel")
# Out:
#   Week_days count
# 1 1         11566
# 2 2         11721
# 3 3         13288
# 4 4         14212
# 5 5         13204
# 6 6         12926
# 7 7         12133
# Warning message:
# “Ignoring unknown parameters: state”
# plot without title

# %% [markdown]
# **Wednesday is the most common day of week in Washington as well**

# %% [markdown]
# ### What is the common day of week in Chicago?

# %%
## Chicago
## most common day of week?
datetime <- ymd_hms(chi$Start.Time)
Most.Often.Day <- table(wday(datetime, abbr = FALSE))
Most.Often.Day.df <- as.data.frame(Most.Often.Day)
names(Most.Often.Day.df) <- c("Week_days", "count")
Most.Often.Day.df 

## visual representation of data

ggplot(Most.Often.Day.df, aes(x= Week_days, y = count, group = 1)) +
  geom_line(state = "identity")+
  labs(title = "this plot represents week days of travel")
# Out:
#   Week_days count
# 1 1         1111
# 2 2         1302
# 3 3         1292
# 4 4         1236
# 5 5         1254
# 6 6         1285
# 7 7         1150
# Warning message:
# “Ignoring unknown parameters: state”
# plot without title

# %% [markdown]
# **Monday is the most common day of week in Chicago**

# %% [markdown]
# ### What is the common hour of day in Newyork?

# %%
## New York City

## most common hour of the day to travel

datetime <- ymd_hms(newyork$Start.Time)
Most.Often.hour <- table(hour(datetime))
Most.Often.hour.df <- as.data.frame(Most.Often.hour)
names(Most.Often.hour.df) <- c("Hours_of_day", "count")
Most.Often.hour.df


##visualization
ggplot(Most.Often.hour.df, aes(x= Hours_of_day, y = count, group = 1)) +
  geom_line(state = "identity")
# Out:
#    Hours_of_day count
# 1  0             436
# 2  1             231
# 3  2             152
# 4  3              60
# 5  4              84
# 6  5             312
# 7  6            1212
# 8  7            2512
# 9  8            4337
# 10 9            3521
# 11 10           2471
# 12 11           2643
# 13 12           2866
# 14 13           3054
# 15 14           3157
# 16 15           3356
# 17 16           3894
# 18 17           5503
# 19 18           5281
# 20 19           3594
# 21 20           2437
# 22 21           1646
# 23 22           1214
# 24 23            797
# Warning message:
# “Ignoring unknown parameters: state”
# plot without title

# %% [markdown]
# **17th is the most common hour of the day in New York.**

# %% [markdown]
# ### What is the common hour of day in Washington?

# %%
## Washington City

## Washington City
datetime <- ymd_hms(wash$Start.Time)
Most.Often.hour <- table(hour(datetime))
Most.Often.hour.df <- as.data.frame(Most.Often.hour)
names(Most.Often.hour.df) <- c("Hours_of_day", "count")
Most.Often.hour.df


##visualization
ggplot(Most.Often.hour.df, aes(x= Hours_of_day, y = count, group = 1)) +
  geom_line(state = "identity") +
  labs(title = "this plot represent hours of the day")
# Out:
#    Hours_of_day count
# 1  0             227
# 2  1            3500
# 3  2            3421
# 4  3            3655
# 5  4            4541
# 6  5            6741
# 7  6            6994
# 8  7            8490
# 9  8            9805
# 10 9            5957
# 11 10           4788
# 12 11           5057
# 13 12           5569
# 14 13           1906
# 15 14           1774
# 16 15           2136
# 17 16           2746
# 18 17           3958
# 19 18           3028
# 20 19           1772
# 21 20           1181
# 22 21            855
# 23 22            605
# 24 23            344
# Warning message:
# “Ignoring unknown parameters: state”
# plot without title

# %% [markdown]
# **8th is the most common hour of the day**

# %% [markdown]
# ### What is the common hour of day in Chicago?

# %%
## Chicago City
datetime <- ymd_hms(chi$Start.Time)
Most.Often.hour <- table(hour(datetime))
Most.Often.hour.df <- as.data.frame(Most.Often.hour)
names(Most.Often.hour.df) <- c("Hours_of_day", "count")
Most.Often.hour.df
##visualization
ggplot(Most.Often.hour.df, aes(x= Hours_of_day, y = count, group = 1)) +
  geom_line(state = "identity") +
  geom_point() +
  labs(title = "this plot represent hours of the day")
# Out:
#    Hours_of_day count
# 1  0              55
# 2  1              26
# 3  2              18
# 4  3              16
# 5  4              17
# 6  5              67
# 7  6             243
# 8  7             560
# 9  8             693
# 10 9             385
# 11 10            320
# 12 11            467
# 13 12            482
# 14 13            530
# 15 14            466
# 16 15            599
# 17 16            804
# 18 17           1039
# 19 18            679
# 20 19            435
# 21 20            268
# 22 21            237
# 23 22            146
# 24 23             78
# Warning message:
# “Ignoring unknown parameters: state”
# plot without title

# %% [markdown]
# **17th is the most common hour of the day in Chicago**

# %% [markdown]
# # Question 2
# # Popular station and trip
# ### What is the most common start station in New York?

# %%
# Your solution code goes here

##New York
start_station_tb <- table(newyork$Start.Station)
start_station_tb[which.max(start_station_tb)]
# Out:
# Pershing Square North
#                   592

# %% [markdown]
# ### What is the most common start station in Washington?

# %%
## Washington
start_station_tb <- table(wash$Start.Station)
start_station_tb[which.max(start_station_tb)]
# Out:
# Columbus Circle / Union Station
#                            1700

# %% [markdown]
# ### What is the most common start station in Chicago?

# %%
## Chicago
start_station_tb <- table(chi$Start.Station)
start_station_tb[which.max(start_station_tb)]
# Out:
# Streeter Dr & Grand Ave
#                     210

# %% [markdown]
# ### What is the most common End station in New York?

# %%
## Newyork
End_station_tb <- table(newyork$End.Station)
End_station_tb[which.max(End_station_tb)]
# Out:
# Pershing Square North
#                   556

# %% [markdown]
# ### What is the most common End station in Washington?

# %%
## Washington
End_station_tb <- table(wash$End.Station)
End_station_tb[which.max(End_station_tb)]
# Out:
# Columbus Circle / Union Station
#                            1767

# %% [markdown]
# ### What is the most common End station in Chicago?

# %%
## Chicago
End_station_tb <- table(chi$End.Station)
End_station_tb[which.max(End_station_tb)]
# Out:
# Streeter Dr & Grand Ave
#                     233

# %% [markdown]
# ### What is the most common trip from start to end(i.e., most frequent combination of start station and end station)?

# %% [markdown]
# **Summary of your question 2 results goes here.**

# %% [markdown]
# # Question 3
# # Trip Duration
# ### What is the total travel time for users in New York city?
#
# **Your question 3 goes here.**

# %%
# Your solution code goes 
library(dplyr)
newyork %>%
group_by(User.Type) %>%
summarise(Total.Travel.Time = sum(Trip.Duration))


## sum of travel time for all users
total.travel.time <- sum(newyork[,'Trip.Duration'], na.rm = TRUE)
print(total.travel.time)
# Out:
#   User.Type  Total.Travel.Time
# 1                  NA
# 2 Customer   12189116
# 3 Subscriber 37084015
# [1] 49490073

# %% [markdown]
# ### What is the total travel time for users in Washington city?

# %%
# Your solution code goes 
library(dplyr)
wash %>%
group_by(User.Type) %>%
summarise(Total.Travel.Time = sum(Trip.Duration))


## sum of travel time for all users 
total.travel.time <- sum(wash[,'Trip.Duration'], na.rm = TRUE)
print(total.travel.time)
# Out:
#   User.Type  Total.Travel.Time
# 1                  NA
# 2 Customer   61777358
# 3 Subscriber 48106186
# [1] 109883545

# %% [markdown]
# ### What is the total travel time for users in Chicago city?

# %%
# Your solution code goes 
library(dplyr)
chi %>%
group_by(User.Type) %>%
summarise(Total.Travel.Time = sum(Trip.Duration))


## sum of travel time for all users 
total.travel.time <- sum(chi[,'Trip.Duration'], na.rm = TRUE)
print(total.travel.time)
# Out:
#   User.Type  Total.Travel.Time
# 1               3020
# 2 Customer   3369740
# 3 Subscriber 4715041
# [1] 8087801

# %% [markdown]
# ### What is the average travel time for users in New York?

# %%
library(tidyverse)
newyork %>%
group_by(User.Type) %>%
summarise(average = mean(Trip.Duration))


## Average of travel time for all users
average.travel.time <-mean(newyork[,'Trip.Duration'], na.rm = TRUE)
average.travel.time
# Out:
#   User.Type  average
# 1                   NA
# 2 Customer   2193.0759
# 3 Subscriber  755.3829
# [1] 903.6147

# %% [markdown]
# ### What is the average travel time for users in Washington?

# %%
library(tidyverse)
wash %>%
group_by(User.Type) %>%
summarise(average = mean(Trip.Duration))


## Average of travel time for all users
average.travel.time <-mean(wash[,'Trip.Duration'], na.rm = TRUE)
average.travel.time
# Out:
#   User.Type  average
# 1                  NA
# 2 Customer   2634.429
# 3 Subscriber  733.326
# [1] 1233.953

# %% [markdown]
# ### What is the average travel time for users in Chicago?

# %%
library(tidyverse)
chi %>%
group_by(User.Type) %>%
summarise(average = mean(Trip.Duration))


## Average of travel time for all users
average.travel.time <-mean(chi[,'Trip.Duration'], na.rm = TRUE)
average.travel.time
# Out:
#   User.Type  average
# 1            3020.000
# 2 Customer   1929.977
# 3 Subscriber  685.027
# [1] 937.1728

# %% [markdown]
# # Question 4
# # User Infor
# ### What are the counts of each user type in New York?
#
# **Your question 3 goes here.**

# %%
## count of user type
user_count <- table(newyork$User.Type)
user_count_dframe = as.data.frame(user_count)
names(user_count_dframe) = c("user_type", "count")
user_count_dframe

## visual representation of count of each user

library(ggplot2)
ggplot(data = user_count_dframe, aes(x=user_type,
                                                  y = count)) +
  geom_bar(stat = "identity", width = 0.5, fill = "steelblue", color = "black") +
  labs(title = "Plot represents count of each user type") +
  geom_text(aes(label=count), vjust=1.6, color="black",
            position = position_dodge(0.9), size=3.5)
# Out:
#   user_type  count
# 1              119
# 2 Customer    5558
# 3 Subscriber 49093
# plot without title

# %% [markdown]
# ### What is are the counts of each user type in Washington city?
#
# **Your question 3 goes here.**

# %%
##Count of user type in Washiton city

user_w_count <- table(wash$User.Type)
user_w_dframe <- as.data.frame(user_w_count)
names(user_w_dframe) = c("user_type", "count")
user_w_dframe


## visual representation of count of user type in Washington
library(ggplot2)
ggplot(data = user_w_dframe, aes(x=user_type,
                                     y = count)) +
  geom_bar(stat = "identity", width = 0.5, fill = "orchid", color = "black") +
  labs(title = "Plot represents count of each user type") +
  geom_text(aes(label=count), vjust=1.6, color="black",
            position = position_dodge(0.9), size=3.5)
# Out:
#   user_type  count
# 1                1
# 2 Customer   23450
# 3 Subscriber 65600
# plot without title

# %% [markdown]
# ### What are the counts of each user in Chicago city?
#
# **Your question 3 goes here.**

# %%
user_chi_count <- table(chi$User.Type)
user_chi_dframe <- as.data.frame(user_chi_count)
names(user_chi_dframe) <- c("user_type", "count")
user_chi_dframe


## visual representation of count of user type in Chicago city
library(ggplot2)
ggplot(data = user_chi_dframe, aes(x=user_type,
                                 y = count)) +
  geom_bar(stat = "identity", width = 0.5, fill = "chocolate2", color = "black") +
  labs(title = "Plot represents count of each user type") +
  geom_text(aes(label=count), vjust=1.6, color="black",
            position = position_dodge(0.9), size=3.5)
# Out:
#   user_type  count
# 1               1
# 2 Customer   1746
# 3 Subscriber 6883
# plot without title

# %% [markdown]
# ### What is the counts of each gender in New York?
#
# **Your question 3 goes here.**

# %%
## counts of each gender type
gender_count_ny <- table(newyork$Gender)
gender_count_dframe <- as.data.frame(gender_count_ny)
names(gender_count_dframe) <- c("gender_type", "count")
gender_count_dframe


## visual representation of count of gender in New York
library(ggplot2)
ggplot(data = gender_count_dframe, aes(x=gender_type,
                                   y = count)) +
  geom_bar(stat = "identity", width = 0.5, fill = "peachpuff", color = "black") +
  labs(title = "Plot represents count of each user type") +
  geom_text(aes(label=count), hjust=1.3, color="black") +
  coord_flip()
# Out:
#   gender_type count
# 1              5410
# 2 Female      12159
# 3 Male        37201
# plot without title

# %% [markdown]
# ### What is the counts of each gender type in Chicago city?
#
# **Your question 3 goes here.**

# %%
# counts of each gender type
gender_chi_count <- table(chi$Gender)
gender_count_chi_dframe <- as.data.frame(gender_chi_count)
names(gender_count_chi_dframe) <- c("gender_type", "count")
gender_count_chi_dframe

# visual representation of count of gender in Chicago
library(ggplot2)
ggplot(data = gender_count_dframe, aes(x=gender_type,
                                   y = count)) +
  geom_bar(stat = "identity", width = 0.5, fill = "darkslategray3", color = "black") +
  labs(title = "Plot represents count of each user type") +
  geom_text(aes(label=count), hjust=1.3, color="black") +
  coord_flip()
# Out:
#   gender_type count
# 1             1748
# 2 Female      1723
# 3 Male        5159
# plot without title

# %% [markdown]
# ### What are the earliest, most recent, most common year of birth in New York?
#
# **Your question 3 goes here.**

# %%
##What are the earliest, most recent, most common year of birth(only availabe for NYC and Chicago)

library(dplyr)
## New York city
## the most earliest and most recent year of birth
summary(newyork$Birth.Year)

## the most common year of birth
birth_year_dframe <- as.data.frame(table(newyork$Birth.Year))
names(birth_year_dframe) <- c("Birth_year", "count")

ggplot(birth_year_dframe, aes(x = Birth_year, y = count, group = 1)) +
  geom_line(stat = "identity", position = "identity") +
  scale_x_discrete(breaks = c(1885,1940,1952,1976,1989,2001)) +
  labs(title = "This plot represents count of birth years(1885-2001)")
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#    1885    1970    1981    1978    1988    2001    5218
# plot without title

# %% [markdown]
# ### What are the earliest, most recent, most common year of birth in Chicago?
#
# **Your question 3 goes here.**

# %%
## Chicago city
## the most earliest and most recent year of birth

summary(chi$Birth.Year)

## the most common year of birth
birth_year_dframe_chi <- as.data.frame(table(chi$Birth.Year))
names(birth_year_dframe_chi) <- c("Birth_year", "count")


ggplot(birth_year_dframe_chi, aes(x = Birth_year, y = count, group = 1)) +
  geom_line(stat = "identity", position = "identity") +
  scale_x_discrete(breaks = c(1899,1940,1952,1976,1989,2016)) +
  labs(title = "This plot represents count of birth years(1889-2016)")
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#    1899    1975    1984    1981    1989    2002    1747
# plot without title

# %% [markdown]
# ## Finishing Up
#
# > Congratulations!  You have reached the end of the Explore Bikeshare Data Project. You should be very proud of all you have accomplished!
#
# > **Tip**: Once you are satisfied with your work here, check over your report to make sure that it is satisfies all the areas of the [rubric](https://review.udacity.com/#!/rubrics/2508/view).
#
#
# ## Directions to Submit
#
# > Before you submit your project, you need to create a .html or .pdf version of this notebook in the workspace here. To do that, run the code cell below. If it worked correctly, you should get a return code of 0, and you should see the generated .html file in the workspace directory (click on the orange Jupyter icon in the upper left).
#
# > Alternatively, you can download this report as .html via the **File** > **Download as** submenu, and then manually upload it into the workspace directory by clicking on the orange Jupyter icon in the upper left, then using the Upload button.
#
# > Once you've done this, you can submit your project by clicking on the "Submit Project" button in the lower right here. This will create and submit a zip file with this .ipynb doc and the .html or .pdf version you created. Congratulations!

# %%
system('python -m nbconvert Explore_bikeshare_data.ipynb')
